# %%
import numpy as np
import matplotlib.pyplot as plt
from SASPKineticModel import SASPKineticModel

# %%
model = SASPKineticModel()

# %%
model.plot_exp_data()

# %%
model.optimize([3, 2, 0.75, 1.25, 1, 1, 0, 0])

# %%
model.plot_model(comp_no=2)

# %%
model.plot_model(comp_no=0)

# %%
model.plot_model(comp_no=3)
# Out:
# Percent of SASP excreted via urine: 2.955%

# %%
model.knockout(rates=[0])
# Out:
# PEAK CONC. FOLD CHANGE: 0.7975193778628027
# AUC FOLD CHANGE: 0.9269996814346478

# %%
model.knockout(rates=[1])
# Out:
# PEAK CONC. FOLD CHANGE: 0.4200796145040856
# AUC FOLD CHANGE: 0.4724334953620581

# %%
model.knockout(rates=[0,1])
# Out:
# PEAK CONC. FOLD CHANGE: 2.8541710300188337
# AUC FOLD CHANGE: 4.020909282838648

# %%
model.knockout(rates=[3])
# Out:
# PEAK CONC. FOLD CHANGE: 0.6189462804981025
# AUC FOLD CHANGE: 0.6371692931952729

# %%
# Plasma 
model.model_bact()
# Out:
# PEAK CONC. FOLD CHANGE: 2.2165591510760425 for BACTERIA: E. coli Nissle 1917 and CONDITION: aerobic
# Simulated EColi. aerobic:
# BCRP
# 		mean: 0.09551761694840538
# 		std: 0.16735989514225605
#
# MRP2
# 		mean: 0.1137733725564753
# 		std: 0.08321870621886224
#
# OATP2B1
# 		mean: 1.1251144843942056
# 		std: 0.8362488044201832
# PEAK CONC. FOLD CHANGE: 0.3724961079724992 for BACTERIA: E. coli Nissle 1917 and CONDITION: anaerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 0.12245912905298417
# 		std: 0.16093036486925347
#
# MRP2
# 		mean: 4.443377425166096
# 		std: 2.530951296406954
#
# OATP2B1
# 		mean: 0.22565099977379435
# 		std: 0.06788486173608212
# PEAK CONC. FOLD CHANGE: 1.634429718559082 for BACTERIA: Bifidobacterium adolescentis and CONDITION: aerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 0.031680845444867475
# 		std: 0.04621710488516523
#
# MRP2
# 		mean: 0.05815180717703306
# 		std: 0.11102769013190672
#
# OATP2B1
# 		mean: 0.5014056395563372
# 		std: 0.04092150786797967
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PEAK CONC. FOLD CHANGE: 0.051632048860727274 for BACTERIA: Bifidobacterium adolescentis and CONDITION: anaerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 1.364736861364336
# 		std: 1.9132371653402767
#
# MRP2
# 		mean: 2.0134785170991707
# 		std: 0.38989039345292137
#
# OATP2B1
# 		mean: 0.6174081956379752
# 		std: 1.3061200249210718
# C:\Users\backs\scripts\PK\Bacteria_Pharmacokinetics\SASPKineticModel.py:388: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
# Lumen
model.model_bact(comp_no=0)
# Out:
# PEAK CONC. FOLD CHANGE: 5.860498283096547e-16 for BACTERIA: E. coli Nissle 1917 and CONDITION: aerobic
# Simulated EColi. aerobic:
# BCRP
# 		mean: 0.0880444564613612
# 		std: 0.13029473654369694
#
# MRP2
# 		mean: 0.10741143759595721
# 		std: 0.0752997649780939
#
# OATP2B1
# 		mean: 1.1142821080171186
# 		std: 0.7888912649156333
# PEAK CONC. FOLD CHANGE: 5.860498283096547e-16 for BACTERIA: E. coli Nissle 1917 and CONDITION: anaerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 0.13947858203227098
# 		std: 0.42247767781833606
#
# MRP2
# 		mean: 4.630923835629879
# 		std: 2.7414990559888004
#
# OATP2B1
# 		mean: 0.22842945389918845
# 		std: 0.07260161669975727
# PEAK CONC. FOLD CHANGE: 5.860498283096547e-16 for BACTERIA: Bifidobacterium adolescentis and CONDITION: aerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 0.03353340560377478
# 		std: 0.06717097071915995
#
# MRP2
# 		mean: 0.05660459090639172
# 		std: 0.10061375057863303
#
# OATP2B1
# 		mean: 0.49822518516587344
# 		std: 0.04167206845914461
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PEAK CONC. FOLD CHANGE: 5.860498283096547e-16 for BACTERIA: Bifidobacterium adolescentis and CONDITION: anaerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 1.3671184342625284
# 		std: 1.832326161524847
#
# MRP2
# 		mean: 2.0269683557728433
# 		std: 0.40695312178143767
#
# OATP2B1
# 		mean: 0.6570944576399242
# 		std: 1.4993227606351145

# %%
# Metabolites
model.model_bact(comp_no=4)
# Out:
# PEAK CONC. FOLD CHANGE: 0.09603562911547708 for BACTERIA: E. coli Nissle 1917 and CONDITION: aerobic
# Simulated EColi. aerobic:
# BCRP
# 		mean: 0.08881050842976272
# 		std: 0.1662295978666474
#
# MRP2
# 		mean: 0.10807055101066185
# 		std: 0.07878112573616922
#
# OATP2B1
# 		mean: 1.1011066825852107
# 		std: 0.7489589901104182
# PEAK CONC. FOLD CHANGE: 0.011645403705746517 for BACTERIA: E. coli Nissle 1917 and CONDITION: anaerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 0.12851020783801537
# 		std: 0.16269892843080308
#
# MRP2
# 		mean: 4.324989354810272
# 		std: 2.479062483132635
#
# OATP2B1
# 		mean: 0.2206383237956339
# 		std: 0.0701372101548205
# PEAK CONC. FOLD CHANGE: 0.06489776982342713 for BACTERIA: Bifidobacterium adolescentis and CONDITION: aerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 0.03484271298380978
# 		std: 0.06195752081388454
#
# MRP2
# 		mean: 0.0575413163420378
# 		std: 0.10694582304744733
#
# OATP2B1
# 		mean: 0.4982713415625186
# 		std: 0.04137485722025833
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PEAK CONC. FOLD CHANGE: 0.0008526144848909037 for BACTERIA: Bifidobacterium adolescentis and CONDITION: anaerobic
# Simulated EColi. anaerobic:
# BCRP
# 		mean: 1.5319985475819982
# 		std: 2.9904262753584008
#
# MRP2
# 		mean: 2.0444190012409718
# 		std: 0.40394993543810276
#
# OATP2B1
# 		mean: 0.6050354063534228
# 		std: 1.2733267384045084
