# %%
import numpy as np
import matplotlib.pyplot as plt
from SASPKineticModel import SASPKineticModel

# %%
model = SASPKineticModel()

# %%
model.plot_exp_data()

# %%
model.optimize([3, 2, 0.75, 1.25, 1, 1, 0, 0])

model.rates
# Out:
# array([2.95464943, 1.95464943, 0.75062549, 1.25009501, 0.95784715,
#        0.24246979, 0.0313838 , 0.16160569])

# %%
model.plot_model(comp_no=2)

# %%
model.plot_model(comp_no=0)

# %%
model.plot_model(comp_no=3)
# Out:
# Percent of SASP excreted via urine: 4.196%

# %%
model.knockout(rates=[0])
# Out:
# PEAK CONC. FOLD CHANGE: 0.735098744010062
# AUC FOLD CHANGE: 0.9180281324102939

# %%
model.knockout(rates=[1])
# Out:
# PEAK CONC. FOLD CHANGE: 0.39129714666031024
# AUC FOLD CHANGE: 0.4636905388652618

# %%
model.knockout(rates=[0,1])
# Out:
# PEAK CONC. FOLD CHANGE: 2.2753562190473553
# AUC FOLD CHANGE: 3.819277025371684

# %%
model.knockout(rates=[3])
# Out:
# PEAK CONC. FOLD CHANGE: 0.5884214267663477
# AUC FOLD CHANGE: 0.6142975282040591

# %%
# Plasma 
model.model_bact()

# %%
# Lumen
model.model_bact(comp_no=0)

# %%
# Metabolites
model.model_bact(comp_no=4)
