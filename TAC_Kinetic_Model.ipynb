# %%
import numpy as np
import matplotlib.pyplot as plt
from TACKineticModel import TACKineticModel

# %%
model = TACKineticModel()

# %%
model.plot_exp_data()

# %%
model.optimize([0.048, 1.048, 0.0, 0.069, 0.069, 1.048])

# %%
model.plot_model()

# %%
model.knockout(rates=[1])
# Out:
# PEAK CONC. FOLD CHANGE: 0.8384049231307603
# AUC FOLD CHANGE: 0.9820780727735174

# %%
model.knockout(rates=[3,4])
# Out:
# PEAK CONC. FOLD CHANGE: 0.26409124200764883
# AUC FOLD CHANGE: 1.0520372841983128

# %%
model.model_bact()
