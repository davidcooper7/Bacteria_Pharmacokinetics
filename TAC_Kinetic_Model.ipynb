# %%
import numpy as np
import matplotlib.pyplot as plt
from TACKineticModel import TACKineticModel

# %%
model = TACKineticModel()

# %%
model.plot_exp_data()

# %%
model.optimize([0.0, 1.048, 0.0, 0.069, 0.069, 1.048])

# %%
model.plot_model()

# %%
model.knockout(rates=[1])
# Out:
# PEAK CONC. FOLD CHANGE: 0.8748655106820311
# AUC FOLD CHANGE: 1.0237558143842906

# %%
model.knockout(rates=[3,4], name='CYP3A4/5 knockout')
# Out:
# PEAK CONC. FOLD CHANGE: 0.2980392357560511
# AUC FOLD CHANGE: 1.049589277281204

# %%
model.rates
# Out:
# array([0.00000000e+00, 1.04800000e+00, 9.83660638e-06, 6.90000000e-02,
#        6.90000000e-02, 1.04800000e+00])

# %%
model.model_bact()
# Out:
# PEAK CONC. FOLD CHANGE: 0.5555245785695226 for BACTERIA: E. coli Nissle 1917 and CONDITION: aerobic
# Simulated EColi. aerobic:
# MRP2
# 		mean: 0.05695134696327578
# 		std: 0.04024492849078278
#
# CYP3A4
# 		mean: 1.3763967902938539
# 		std: 0.1416516929285982
# PEAK CONC. FOLD CHANGE: 0.45969067368951005 for BACTERIA: E. coli Nissle 1917 and CONDITION: anaerobic
# Simulated EColi. aerobic:
# MRP2
# 		mean: 2.3141960024030865
# 		std: 1.4311359088963276
#
# CYP3A4
# 		mean: 0.2401575787167792
# 		std: 0.08683979456222353
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PEAK CONC. FOLD CHANGE: 0.3773851721535314 for BACTERIA: Bifidobacterium adolescentis and CONDITION: aerobic
# Simulated EColi. aerobic:
# MRP2
# 		mean: 0.03202946371035415
# 		std: 0.10958731953497604
#
# CYP3A4
# 		mean: 1.0386728510902576
# 		std: 0.15380557441071382
# ...
